# %% [markdown]
# Librarys

# %%
import pandas as pd
import requests
import os

# %% [markdown]
# Read CSV

# %%
url = "https://www.irs.gov/pub/irs-soi/19zpallagi.csv"
response = requests.get(url)
with open(os.path.join(".", "19zpallagi.csv"), 'wb') as f:
    f.write(response.content)
file = '19zpallagi.csv'

# %%
pd_df = pd.read_csv(file)

# %%
pd_df.head(5)
# Out:
#    STATEFIPS STATE  zipcode  agi_stub        N1     mars1     MARS2     MARS4  \
# 0          1    AL        0         1  778210.0  491030.0   84770.0  189600.0
# 1          1    AL        0         2  525940.0  247140.0  123910.0  139860.0
# 2          1    AL        0         3  285700.0  105140.0  128140.0   44560.0
# 3          1    AL        0         4  179070.0   38820.0  123110.0   13740.0
# 4          1    AL        0         5  257010.0   28180.0  216740.0    7150.0
#
#         ELF    CPREP  ...  N85300  A85300    N11901    A11901    N11900  \
# 0  712890.0  30670.0  ...     0.0     0.0   62720.0   51936.0  671860.0
# 1  481760.0  18960.0  ...     0.0     0.0   85860.0  122569.0  438020.0
# 2  260570.0  10670.0  ...     0.0     0.0   73980.0  154932.0  212040.0
# 3  164300.0   5020.0  ...     0.0     0.0   51330.0  139065.0  126850.0
# 4  236850.0   8400.0  ...    90.0   141.0  104290.0  460071.0  152790.0
#
#       A11900    N11902     A11902  N12000   A12000
# ...

# %% [markdown]
# Shape

# %%
print('Rows: '+str(pd_df.shape[0]),' x ','Columns: '+str(pd_df.shape[1]))
# Out:
# Rows: 166159  x  Columns: 152

# %% [markdown]
# Select few columns

# %%
col_names = ['STATEFIPS', 'STATE', 'zipcode', 'agi_stub', 'N1']

# %%
pd_df2 = pd.read_csv(file, usecols=col_names)

# %%
print('Rows: '+str(pd_df2.shape[0]),' x ','Columns: '+str(pd_df2.shape[1]))
# Out:
# Rows: 166159  x  Columns: 5

# %% [markdown]
# Select sample

# %%
pd_df3 = pd.read_csv(file, usecols=col_names, nrows=1000)

# %%
print('Rows: '+str(pd_df3.shape[0]),' x ','Columns: '+str(pd_df3.shape[1]))
# Out:
# Rows: 1000  x  Columns: 5

# %% [markdown]
# Schema

# %%
pd_df.dtypes
# Out:
# STATEFIPS      int64
# STATE         object
# zipcode        int64
# agi_stub       int64
# N1           float64
#               ...
# A11900       float64
# N11902       float64
# A11902       float64
# N12000       float64
# A12000       float64
# Length: 152, dtype: object

# %%
pd_df = pd.read_csv(file, dtype={'zipcode':str})

# %%
pd_df.dtypes
# Out:
# STATEFIPS      int64
# STATE         object
# zipcode       object
# agi_stub       int64
# N1           float64
#               ...
# A11900       float64
# N11902       float64
# A11902       float64
# N12000       float64
# A12000       float64
# Length: 152, dtype: object

# %% [markdown]
# Missing Values

# %%
pd_df.head(5)
# Out:
#    STATEFIPS STATE zipcode  agi_stub        N1     mars1     MARS2     MARS4  \
# 0          1    AL   00000         1  778210.0  491030.0   84770.0  189600.0
# 1          1    AL   00000         2  525940.0  247140.0  123910.0  139860.0
# 2          1    AL   00000         3  285700.0  105140.0  128140.0   44560.0
# 3          1    AL   00000         4  179070.0   38820.0  123110.0   13740.0
# 4          1    AL   00000         5  257010.0   28180.0  216740.0    7150.0
#
#         ELF    CPREP  ...  N85300  A85300    N11901    A11901    N11900  \
# 0  712890.0  30670.0  ...     0.0     0.0   62720.0   51936.0  671860.0
# 1  481760.0  18960.0  ...     0.0     0.0   85860.0  122569.0  438020.0
# 2  260570.0  10670.0  ...     0.0     0.0   73980.0  154932.0  212040.0
# 3  164300.0   5020.0  ...     0.0     0.0   51330.0  139065.0  126850.0
# 4  236850.0   8400.0  ...    90.0   141.0  104290.0  460071.0  152790.0
#
#       A11900    N11902     A11902  N12000   A12000
# ...

# %%
pd_df = pd.read_csv(file,dtype={'zipcode':str},na_values={'zipcode':'00000'})

# %%
pd_df = pd_df[pd_df.zipcode.isna()]

# %%
pd_df.head(5)
# Out:
#    STATEFIPS STATE zipcode  agi_stub        N1     mars1     MARS2     MARS4  \
# 0          1    AL     NaN         1  778210.0  491030.0   84770.0  189600.0
# 1          1    AL     NaN         2  525940.0  247140.0  123910.0  139860.0
# 2          1    AL     NaN         3  285700.0  105140.0  128140.0   44560.0
# 3          1    AL     NaN         4  179070.0   38820.0  123110.0   13740.0
# 4          1    AL     NaN         5  257010.0   28180.0  216740.0    7150.0
#
#         ELF    CPREP  ...  N85300  A85300    N11901    A11901    N11900  \
# 0  712890.0  30670.0  ...     0.0     0.0   62720.0   51936.0  671860.0
# 1  481760.0  18960.0  ...     0.0     0.0   85860.0  122569.0  438020.0
# 2  260570.0  10670.0  ...     0.0     0.0   73980.0  154932.0  212040.0
# 3  164300.0   5020.0  ...     0.0     0.0   51330.0  139065.0  126850.0
# 4  236850.0   8400.0  ...    90.0   141.0  104290.0  460071.0  152790.0
#
#       A11900    N11902     A11902  N12000   A12000
# ...

# %% [markdown]
# Unparseable records

# %%
pd_df = (
    pd.read_csv(
        file,
        dtype={'zipcode':str},
        na_values={'zipcode':'00000'},
        on_bad_lines='skip'
    )
)

# %%
pd_df.head(5)
# Out:
#    STATEFIPS STATE zipcode  agi_stub        N1     mars1     MARS2     MARS4  \
# 0          1    AL     NaN         1  778210.0  491030.0   84770.0  189600.0
# 1          1    AL     NaN         2  525940.0  247140.0  123910.0  139860.0
# 2          1    AL     NaN         3  285700.0  105140.0  128140.0   44560.0
# 3          1    AL     NaN         4  179070.0   38820.0  123110.0   13740.0
# 4          1    AL     NaN         5  257010.0   28180.0  216740.0    7150.0
#
#         ELF    CPREP  ...  N85300  A85300    N11901    A11901    N11900  \
# 0  712890.0  30670.0  ...     0.0     0.0   62720.0   51936.0  671860.0
# 1  481760.0  18960.0  ...     0.0     0.0   85860.0  122569.0  438020.0
# 2  260570.0  10670.0  ...     0.0     0.0   73980.0  154932.0  212040.0
# 3  164300.0   5020.0  ...     0.0     0.0   51330.0  139065.0  126850.0
# 4  236850.0   8400.0  ...    90.0   141.0  104290.0  460071.0  152790.0
#
#       A11900    N11902     A11902  N12000   A12000
# ...

# %% [markdown]
# ### FreeCodeCamp New Developer Survey response subset

# %% [markdown]
# Librarys

# %%
import pandas as pd
import requests
import os

# %% [markdown]
# Read Spreadsheet

# %%
url = "https://assets.datacamp.com/production/repositories/4412/datasets/fdb113aa942a0e0ad5c155b2f04784886f0038c9/fcc-new-coder-survey.xlsx"
response = requests.get(url)
with open(os.path.join(".", "fcc-new-coder-survey.xlsx"), 'wb') as f:
    f.write(response.content)
file = 'fcc-new-coder-survey.xlsx'

# %%
survey_data = pd.read_excel(file,skiprows=[0,1])

# %%
survey_data.head(5)
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo BootcampName  \
# 0  28.0               0.0             NaN                NaN          NaN
# 1  22.0               0.0             NaN                NaN          NaN
# 2  19.0               0.0             NaN                NaN          NaN
# 3  26.0               0.0             NaN                NaN          NaN
# 4  20.0               0.0             NaN                NaN          NaN
#
#    BootcampRecommend  ChildrenNumber                 CityPopulation  \
# 0                NaN             NaN  between 100,000 and 1 million
# 1                NaN             NaN  between 100,000 and 1 million
# 2                NaN             NaN            more than 1 million
# 3                NaN             NaN            more than 1 million
# 4                NaN             NaN  between 100,000 and 1 million
#
#    CodeEventConferences  CodeEventDjangoGirls  ...  ResourcePluralSight  \
# ...

# %% [markdown]
# Employment Columns

# %%
employment = pd.read_excel(file,skiprows=2, usecols='W:AB, AR')

# %%
employment.head(5)
# Out:
#    CommuteTime            CountryCitizen               CountryLive  \
# 0         35.0  United States of America  United States of America
# 1         90.0  United States of America  United States of America
# 2         45.0  United States of America  United States of America
# 3         45.0  United States of America  United States of America
# 4         10.0  United States of America  United States of America
#
#                          EmploymentField EmploymentFieldOther  \
# 0      office and administrative support                  NaN
# 1                      food and beverage                  NaN
# 2                                finance                  NaN
# 3  arts, entertainment, sports, or media                  NaN
# 4                              education                  NaN
#
#      EmploymentStatus   Income
# 0  Employed for wages  32000.0
# 1  Employed for wages  15000.0
# 2  Employed for wages  48000.0
# 3  Employed for wages  43000.0
# ...

# %% [markdown]
# Load Sheets

# %%
survey_2017 = pd.read_excel(file,skiprows=2,sheet_name='2017')

# %%
survey_2017.head(5)
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo BootcampName  \
# 0  27.0               0.0             NaN                NaN          NaN
# 1  34.0               0.0             NaN                NaN          NaN
# 2  21.0               0.0             NaN                NaN          NaN
# 3  26.0               0.0             NaN                NaN          NaN
# 4  20.0               0.0             NaN                NaN          NaN
#
#    BootcampRecommend  ChildrenNumber                 CityPopulation  \
# 0                NaN             NaN            more than 1 million
# 1                NaN             NaN              less than 100,000
# 2                NaN             NaN            more than 1 million
# 3                NaN             NaN  between 100,000 and 1 million
# 4                NaN             NaN  between 100,000 and 1 million
#
#    CodeEventConferences  CodeEventDjangoGirls  ...  ResourcePluralSight  \
# ...

# %% [markdown]
# All sheets

# %%
survey = pd.DataFrame()

# %%
survey_response = pd.read_excel(file,skiprows=2,sheet_name=None)

# %%
for sheet_name, frame in survey_response.items():
    frame['Year'] = sheet_name
    survey = survey.append(frame)

# %%
survey.Year.unique()
# Out:
# array(['2016', '2017'], dtype=object)

# %% [markdown]
# To Booleans

# %%
survey_bool = survey[['ID.x','AttendedBootcamp','BootcampLoanYesNo']]

# %%
survey_bool.sum()
# Out:
# ID.x                 cef35615d61b202f1dc794ef2746df14323e5a113644d1...
# AttendedBootcamp                                                 166.0
# BootcampLoanYesNo                                                 53.0
# dtype: object

# %%
survey_bool.isna().sum()
# Out:
# ID.x                    0
# AttendedBootcamp       20
# BootcampLoanYesNo    1836
# dtype: int64

# %%
survey_bool = (pd.read_excel(
    file,
    skiprows=2,
    sheet_name='2017',
    keep_default_na=False,
    dtype={'AttendedBootcamp':bool,'BootcampLoanYesNo':bool},
    true_values=['Yes'],
    false_values=['No']
    )
)

# %%
survey_bool = survey_bool[['ID.x','AttendedBootcamp','BootcampLoanYesNo']]

# %%
survey_bool.sum()
# Out:
# ID.x                 02d9465b21e8bd09374b0066fb2d56145bfef9ecb211ec...
# AttendedBootcamp                                                   129
# BootcampLoanYesNo                                                   39
# dtype: object

# %%
survey_bool.isna().sum()
# Out:
# ID.x                 0
# AttendedBootcamp     0
# BootcampLoanYesNo    0
# dtype: int64

# %% [markdown]
# Parsing Dates

# %%
date_cols = ['Part1StartTime','Part1EndTime','Part2EndTime']

# %%
survey_df = (pd.read_excel(
    file,
    skiprows=2,
    sheet_name='2017',
    parse_dates=date_cols
    )
)

# %%
survey_df = survey_df[['Part1StartTime','Part1EndTime','Part2EndTime']]
survey_df
# Out:
#          Part1StartTime        Part1EndTime        Part2EndTime
# 0   2017-03-09 00:32:59 2017-03-09 00:36:22 2017-03-09 00:59:46
# 1   2017-03-09 00:33:26 2017-03-09 00:37:07 2017-03-09 00:38:59
# 2   2017-03-09 00:33:53 2017-03-09 00:37:58 2017-03-09 00:40:14
# 3   2017-03-09 00:37:45 2017-03-09 00:40:13 2017-03-09 00:42:26
# 4   2017-03-09 00:39:44 2017-03-09 00:42:45 2017-03-09 00:45:42
# ..                  ...                 ...                 ...
# 995 2017-03-09 22:45:44 2017-03-09 23:38:05 2017-03-09 23:40:32
# 996 2017-03-09 23:36:10 2017-03-09 23:38:44 2017-03-09 23:40:16
# 997 2017-03-09 23:35:28 2017-03-09 23:39:11 2017-03-09 23:40:23
# 998 2017-03-09 23:36:15 2017-03-09 23:39:24 2017-03-09 23:42:16
# 999 2017-03-09 23:37:17 2017-03-09 23:39:37 2017-03-09 23:43:47
#
# [1000 rows x 3 columns]

# %% [markdown]
# Databases

# %%
import pandas as pd
from sqlalchemy import create_engine
import requests
import os

# %%
engine = create_engine('sqlite:///data.db')

# %%
url = "https://assets.datacamp.com/production/repositories/4412/datasets/86d5855fd30d02afe8cb563da6057190694c6b86/data.db"
response = requests.get(url)
with open(os.path.join(".", "data.db"), 'wb') as f:
    f.write(response.content)
file = 'data.db'

# %%
weather = pd.read_sql('weather', engine)

# %%
weather = pd.read_sql('SELECT * FROM weather',engine)
weather
# Out:
#          station                         name  latitude  longitude  elevation  \
# 0    USW00094728  NY CITY CENTRAL PARK, NY US  40.77898  -73.96925       42.7
# 1    USW00094728  NY CITY CENTRAL PARK, NY US  40.77898  -73.96925       42.7
# 2    USW00094728  NY CITY CENTRAL PARK, NY US  40.77898  -73.96925       42.7
# 3    USW00094728  NY CITY CENTRAL PARK, NY US  40.77898  -73.96925       42.7
# 4    USW00094728  NY CITY CENTRAL PARK, NY US  40.77898  -73.96925       42.7
# ..           ...                          ...       ...        ...        ...
# 116  USW00094728  NY CITY CENTRAL PARK, NY US  40.77898  -73.96925       42.7
# 117  USW00094728  NY CITY CENTRAL PARK, NY US  40.77898  -73.96925       42.7
# 118  USW00094728  NY CITY CENTRAL PARK, NY US  40.77898  -73.96925       42.7
# 119  USW00094728  NY CITY CENTRAL PARK, NY US  40.77898  -73.96925       42.7
# 120  USW00094728  NY CITY CENTRAL PARK, NY US  40.77898  -73.96925       42.7
#
# ...

# %%
query = """SELECT * FROM hpd311calls WHERE borough = 'BROOKLYN';"""

# %%
brookly_calls = pd.read_sql(query,engine)
brookly_calls
# Out:
#       unique_key created_date agency  complaint_type incident_zip  \
# 0       38072466   01/01/2018    HPD  HEAT/HOT WATER        11213
# 1       38076014   01/01/2018    HPD  HEAT/HOT WATER        11249
# 2       38081044   01/01/2018    HPD  HEAT/HOT WATER        11226
# 3       38074248   01/01/2018    HPD  HEAT/HOT WATER        11219
# 4       38073079   01/01/2018    HPD  HEAT/HOT WATER        11213
# ...          ...          ...    ...             ...          ...
# 31717   38356899   01/31/2018    HPD  HEAT/HOT WATER        11208
# 31718   38354840   01/31/2018    HPD      WATER LEAK        11208
# 31719   38354085   01/31/2018    HPD   PAINT/PLASTER        11225
# 31720   38355908   01/31/2018    HPD  HEAT/HOT WATER        11215
# 31721   38349554   01/31/2018    HPD  HEAT/HOT WATER        11213
#
#             incident_address community_board   borough
# 0            1030 PARK PLACE     08 BROOKLYN  BROOKLYN
# 1             70 ROSS STREET     01 BROOKLYN  BROOKLYN
# ...

# %%
query = """SELECT * FROM hpd311calls WHERE borough = 'BRONX' and complaint_type='PLUMBING';"""
result_set = pd.read_sql(query,engine)
result_set
# Out:
#      unique_key created_date agency complaint_type incident_zip  \
# 0      38080983   01/01/2018    HPD       PLUMBING        10458
# 1      38077514   01/01/2018    HPD       PLUMBING        10459
# 2      38079889   01/01/2018    HPD       PLUMBING        10462
# 3      38081091   01/01/2018    HPD       PLUMBING        10452
# 4      38075523   01/01/2018    HPD       PLUMBING        10457
# ...         ...          ...    ...            ...          ...
# 2011   38349668   01/31/2018    HPD       PLUMBING        10469
# 2012   38357090   01/31/2018    HPD       PLUMBING        10460
# 2013   38354824   01/31/2018    HPD       PLUMBING        10467
# 2014   38355267   01/31/2018    HPD       PLUMBING        10458
# 2015   38350343   01/31/2018    HPD       PLUMBING        10458
#
#              incident_address community_board borough
# 0        215 EAST  197 STREET        07 BRONX   BRONX
# 1          1120 BRYANT AVENUE        03 BRONX   BRONX
# ...

# %%
query = """SELECT * FROM hpd311calls WHERE complaint_type='WATER LEAK' or complaint_type='PLUMBING';"""
result_set = pd.read_sql(query,engine)
result_set
# Out:
#       unique_key created_date agency complaint_type incident_zip  \
# 0       38065299   01/01/2018    HPD       PLUMBING        10003
# 1       38074305   01/01/2018    HPD     WATER LEAK        11212
# 2       38073131   01/01/2018    HPD       PLUMBING        10310
# 3       38081103   01/01/2018    HPD       PLUMBING        11233
# 4       38073127   01/01/2018    HPD       PLUMBING        11230
# ...          ...          ...    ...            ...          ...
# 10679   38350320   01/31/2018    HPD       PLUMBING        11210
# 10680   38351544   01/31/2018    HPD     WATER LEAK        10457
# 10681   38354774   01/31/2018    HPD     WATER LEAK        11435
# 10682   38354840   01/31/2018    HPD     WATER LEAK        11208
# 10683   38350917   01/31/2018    HPD     WATER LEAK        11104
#
#            incident_address   community_board        borough
# 0      323 EAST   12 STREET      03 MANHATTAN      MANHATTAN
# 1      1026 WILLMOHR STREET       17 BROOKLYN       BROOKLYN
# ...

# %%
query = """SELECT borough,COUNT(*) FROM hpd311calls WHERE complaint_type='PLUMBING' GROUP BY borough;"""
result_set = pd.read_sql(query,engine)
result_set
# Out:
#          borough  COUNT(*)
# 0          BRONX      2016
# 1       BROOKLYN      2702
# 2      MANHATTAN      1413
# 3         QUEENS       808
# 4  STATEN ISLAND       178

# %%
query = """SELECT h.borough,COUNT(*), b.total_population, b.housing_units
        FROM hpd311calls h JOIN boro_census b
        ON h.borough = b.borough
        GROUP BY h.borough;"""
result_set = pd.read_sql(query,engine)
result_set
# Out:
#          borough  COUNT(*)  total_population  housing_units
# 0          BRONX     29874           1455846         524488
# 1       BROOKLYN     31722           2635121        1028383
# 2      MANHATTAN     20196           1653877         872645
# 3         QUEENS     11384           2339280         850422
# 4  STATEN ISLAND      1322            475948         179179

# %% [markdown]
# JSON

# %%
import pandas as pd
import requests
import os

# %%
url = "https://data.cityofnewyork.us/resource/jb7j-dtam.json"
response = requests.get(url)
with open(os.path.join(".", "nyc_death_causes.json"), 'wb') as f:
    f.write(response.content)
file = 'nyc_death_causes.json'

# %%
death_causes = pd.read_json(file)

# %%
death_causes
# Out:
#      year                                      leading_cause     sex  \
# 0    2019                          Alzheimer's Disease (G30)  Female
# 1    2019     Diseases of Heart (I00-I09, I11, I13, I20-I51)  Female
# 2    2019                                   All Other Causes  Female
# 3    2019   Insitu or Benign / Uncertain Neoplasms (D00-D48)  Female
# 4    2019                               Septicemia (A40-A41)  Female
# ..    ...                                                ...     ...
# 995  2008                        Diabetes Mellitus (E10-E14)       M
# 996  2008              Malignant Neoplasms (Cancer: C00-C97)       F
# 997  2008  Essential Hypertension and Renal Diseases (I10...       F
# 998  2008     Chronic Liver Disease and Cirrhosis (K70, K73)       M
# 999  2008                                   All Other Causes       F
#
#                  race_ethnicity deaths   death_rate age_adjusted_death_rate
# ...

# %% [markdown]
# API
#
# Get api_key in https://www.yelp.com/login?return_url=%2Fdevelopers%2Fv3%2Fmanage_app

# %%
import pandas as pd
import requests

# %%
api_url = "https://api.yelp.com/v3/businesses/search"

# %%
params = {'term':'bookstore','location':'San Francisco'}

# %%
from getpass import getpass
api_key = getpass()

# %%
headers = {'Authorization':'Bearer {}'.format(api_key)}

# %%
response = requests.get(api_url, params=params,headers=headers)

# %%
response
# Out:
# <Response [200]>

# %%
data = response.json()

# %%
bookstores = pd.DataFrame(data['businesses'])
bookstores.head(2)
# Out:
#                        id                         alias            name  \
# 0  N9c6fjIX7jcuAdWZ6Rj4ZQ   the-booksmith-san-francisco   The Booksmith
# 1  4BI1hK0tQZwQWino8olmTQ  alexander-book-san-francisco  Alexander Book
#
#                                            image_url  is_closed  \
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/_7XYRb...      False
# 1  https://s3-media2.fl.yelpcdn.com/bphoto/Uf_q5T...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/the-booksmith-san-fra...           254
# 1  https://www.yelp.com/biz/alexander-book-san-fr...           199
#
#                                           categories  rating  \
# 0  [{'alias': 'bookstores', 'title': 'Bookstores'...     4.5
# 1  [{'alias': 'bookstores', 'title': 'Bookstores'...     4.5
#
#                                          coordinates transactions price  \
# 0  {'latitude': 37.76931, 'longitude': -122.4512485}           []    $$
# ...

# %% [markdown]
# Nested Json

# %%
import pandas as pd
import requests

# %%
api_url = "https://api.yelp.com/v3/businesses/search"
params = {'term':'bookstore','location':'San Francisco'}

# %%
from getpass import getpass
api_key = getpass()

# %%
headers = {'Authorization':'Bearer {}'.format(api_key)}
response = requests.get(api_url, params=params,headers=headers)
data = response.json()

# %%
bookstores = (pd.json_normalize(
    data['businesses'],
    sep='_',
    record_path='categories',
    meta=['name','alias','rating',['coordinates','latitude'],['coordinates','longitude']],
    meta_prefix='biz_'

     )
)
bookstores.head(2)
# Out:
#         alias                   title       biz_name  \
# 0  bookstores              Bookstores  The Booksmith
# 1        mags  Newspapers & Magazines  The Booksmith
#
#                      biz_alias biz_rating biz_coordinates_latitude  \
# 0  the-booksmith-san-francisco        4.5                 37.76931
# 1  the-booksmith-san-francisco        4.5                 37.76931
#
#   biz_coordinates_longitude
# 0               -122.451249
# 1               -122.451249

# %% [markdown]
# Appending

# %%
import pandas as pd
import requests

# %%
api_url = "https://api.yelp.com/v3/businesses/search"
params = {'term':'bookstore','location':'San Francisco'}

# %%
from getpass import getpass
api_key = getpass()

# %%
headers = {'Authorization':'Bearer {}'.format(api_key)}
response = requests.get(api_url, params=params,headers=headers).json()

# %%
bookstores = pd.json_normalize(response['businesses'],sep='_')

# %%
params['offset'] = 20
next_results = requests.get(api_url, params=params,headers=headers).json()
next_books = pd.json_normalize(response['businesses'],sep='_')

# %%
bookstores = pd.concat([bookstores,next_books],ignore_index=True)
bookstores.head()
# Out:
#                        id                                              alias  \
# 0  N9c6fjIX7jcuAdWZ6Rj4ZQ                        the-booksmith-san-francisco
# 1  4BI1hK0tQZwQWino8olmTQ                       alexander-book-san-francisco
# 2  ngUUOEyCHdLkGnO1I5M4Vg                    green-apple-books-san-francisco
# 3  e9Vd5w1sIiPvvUznzdq_vw     green-apple-books-on-the-park-san-francisco-10
# 4  ip8_lbJ4CRoTAFsId3dl4Q  kinokuniya-bookstore-san-francisco-san-francis...
#
#                                    name  \
# 0                         The Booksmith
# 1                        Alexander Book
# 2                     Green Apple Books
# 3         Green Apple Books on the Park
# 4  Kinokuniya Bookstore - San Francisco
#
#                                            image_url  is_closed  \
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/_7XYRb...      False
# 1  https://s3-media2.fl.yelpcdn.com/bphoto/Uf_q5T...      False
# ...
